# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'AppleGothic' # 폰트 설정
matplotlib.rcParams['font.size'] = 15 # 폰트 사이즈
matplotlib.rcParams['axes.unicode_minus'] = False #그래프 마이너스 표시

# %%
x=[1,2,3]
y=[2,4,8]

# %%
plt.plot(x,y)
# plt.bar(x,y)
plt.title("그래프")
plt.show()

# %%
df = pd.read_excel('../Day5/data/score.xlsx',index_col='지원번호')
df
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    홍길동   가산고  197   90   85  100  95  85      Python
# 2번    유관순   가산고  184   40   35   50  55  25        Java
# 3번    이순신   가산고  168   80   75   70  80  75  Javascript
# 4번    강감찬   가산고  187   40   60   70  75  80         NaN
# 5번     김구   가산고  188   15   20   10  35  10         NaN
# 6번    김유신  디지털고  202   80  100   95  85  80           C
# 7번    홍길자  디지털고  188   55   65   45  40  35      PYTHON
# 8번    홍길순  디지털고  190  100   85   90  95  95          C#

# %%
df.index
# Out:
# Index(['1번', '2번', '3번', '4번', '5번', '6번', '7번', '8번'], dtype='object', name='지원번호')

# %%
# plt.bar(df['이름'],df['키'])
plt.plot(x,y,label="서울", marker='o', linewidth=2, markersize=10) #linestyle=none
plt.title("그래프")
plt.legend(loc='upper right') #upper center lower
plt.show()

# %%
plt.plot(df['이름'], df['국어'], label="국어", marker='o', color="blue")
plt.plot(df['이름'], df['영어'], label="영어", marker='v', color="pink" )
plt.plot(df['이름'], df['수학'], label="수학", marker='x', color="red")
plt.title("학생성적그래프")
plt.legend()
plt.show()

# %%
df1 = pd.read_csv('../Day5/data/stuscore.csv', index_col ='번호')
df1 = df1.head(3)

plt.plot(df1['이름'], df1['국어'], label="국어", marker='o', color="blue")
plt.plot(df1['이름'], df1['영어'], label="영어", marker='v', color="pink" )
plt.plot(df1['이름'], df1['수학'], label="수학", marker='x', color="red")
plt.title("학생성적그래프")
plt.legend()
plt.show()

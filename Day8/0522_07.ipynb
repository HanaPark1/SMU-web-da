# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# matplotlib.rcParams['font.family'] = 'Malgun Gothic'  # windows 한글폰트 연결
matplotlib.rcParams['font.family'] = 'AppleGothic'  # Mac 한글폰트 연결
matplotlib.rcParams['font.size'] = 15                 # 폰트 사이즈
matplotlib.rcParams['axes.unicode_minus'] = False     # 그래프 마이너스 표시

# %%
name = ['홍길동','유관순','이순신']
no = np.arange(1,4)
kor = [100,80,90]
eng = [95,85,92]
math = [-80,-90,-70]

# %%
plt.bar(no,kor,width=0.2)
# plt.barh(no,kor,height=0.2)
plt.xticks(no,name)
plt.show()

# %%
plt.barh(no+0.2,kor,height=0.2)
plt.barh(no,eng,height=0.2)
plt.barh(no-0.2,math,height=0.2)
plt.yticks(no,name)
plt.show()

# %%
plt.plot()
